# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np

# %%
client = MongoClient("mongodb://localhost:27017/")
db = client.companies

# %%
companies = db.companies.find()

# %%
data_companies = pd.DataFrame(companies)

# %%
data_companies.head(3)
# Out:
#                         _id       name permalink  \
# 0  52cdef7c4bab8bd675297d8b  AdventNet      abc3
# 1  52cdef7c4bab8bd675297d8c       Zoho      abc4
# 2  52cdef7c4bab8bd675297d8a   Wetpaint      abc2
#
#                                 crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/adventnet     http://adventnet.com
# 1       http://www.crunchbase.com/company/zoho          http://zoho.com
# 2   http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
#
#                       blog_url                     blog_feed_url  \
# 0
# 1       http://blogs.zoho.com/        http://blogs.zoho.com/feed
# 2  http://digitalquarters.net/  http://digitalquarters.net/feed/
#
#   twitter_username category_code  number_of_employees  ...  \
# 0     manageengine    enterprise                600.0  ...
# 1             zoho      software               1600.0  ...
# 2  BachelrWetpaint           web                 47.0  ...
#
#                                         video_embeds  \
# 0                                                 []
# 1  [{'embed_code': '<object width="430" height="2...
# 2                                                 []
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 94], 'assets/imag...
# 1                                                 []
# 2  [{'available_sizes': [[[150, 86], 'assets/imag...
#
#                                       external_links partners founded_month  \
# 0                                                 []       []           NaN
# 1  [{'external_url': 'http://www.online-tech-tips...       []           9.0
# 2  [{'external_url': 'http://www.geekwire.com/201...       []          10.0
#
#   founded_day deadpooled_month deadpooled_day deadpooled_url  ipo
# 0         NaN              NaN            NaN            NaN  NaN
# 1        15.0              NaN            NaN            NaN  NaN
# 2        17.0              NaN            NaN            NaN  NaN
#
# [3 rows x 42 columns]

# %%
data_companies.shape
# Out:
# (18801, 42)

# %%
data_companies["category_code"].value_counts()
# Out:
# web                 3787
# software            2736
# games_video         1083
# mobile              1018
# other                986
# advertising          928
# enterprise           742
# ecommerce            688
# consulting           637
# network_hosting      626
# public_relations     533
# search               394
# biotech              373
# hardware             368
# cleantech            305
# semiconductor        167
# security             156
# analytics             66
# social                49
# finance               49
# news                  48
# education             36
# music                 33
# messaging             30
# medical               25
# travel                25
# legal                 25
# health                23
# photo_video           23
# manufacturing         19
# sports                13
# real_estate           10
# fashion               10
# automotive             9
# hospitality            8
# transportation         7
# nanotech               5
# design                 4
# nonprofit              4
# local                  1
# government             1
# Name: category_code, dtype: int64

# %%
acquisition = db.companies.find({"$and":[
                               {"founded_year": {"$gte": 2000}},
                               {"total_money_raised":{"$regex":'M'}},
                               {"$or": [
                                   {"category_code": "web" } ,
                                   {"category_code": "software" } ,
                                   {"category_code": "games_video" } ,
                                   ]} ,                                ]
                               },
                                {"_id": 0, "crunchbase_url": 0, "products": 0,
                                "acquisition": 0, "acquisitions": 0, "video_embeds": 0,
                                "screenshots": 0, "external_links": 0, "partners": 0,
                                "image": 0, "blog_feed_url": 0, "blog_url":0, "deadpooled_day":0,
                                "deadpooled_year":0, "deadpooled_month":0, "deadpooled_url":0, "ipo":0,
                                "permalink":0, "homepage_url":0, "tag_list":0, "email_addres": 0, "providerships": 0,
                                "milestones": 0, "twitter_username": 0, "updated_at": 0, "email_address":0, "investments":0,
                               }
                                    )

# %%
acquisition = pd.DataFrame(acquisition)

# %%
acquisition.shape
# Out:
# (1036, 16)

# %%
acquisition.head(3)
# Out:
#        name category_code  number_of_employees  founded_year  founded_month  \
# 0  Wetpaint           web                 47.0          2005           10.0
# 1    Gizmoz           web                  NaN          2003            1.0
# 2      Geni           web                 18.0          2006            6.0
#
#    founded_day alias_list  phone_number                    description  \
# 0         17.0             206.859.6300    Technology Platform Company
# 1          1.0                                         Photo animation
# 2          1.0                           Geneology social network site
#
#                      created_at  \
# 0           2007-05-25 06:51:27
# 1  Fri Jun 01 19:32:24 UTC 2007
# 2  Thu May 31 19:52:34 UTC 2007
#
#                                             overview  \
# 0  <p>Wetpaint is a technology platform company t...
# 1  <p>Founded in 2003, Gizmoz has developed propr...
# 2  <p>Geni is an online community of casual and e...
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'Co-Founder and V...
# 1  [{'is_past': False, 'title': 'Chief Technology...
# 2  [{'is_past': False, 'title': 'CEO', 'person': ...
#
#                                         competitions total_money_raised  \
# 0  [{'competitor': {'name': 'Wikia', 'permalink':...             $39.8M
# 1  [{'competitor': {'name': 'Fix8', 'permalink': ...             $18.1M
# 2  [{'competitor': {'name': 'Ancestry', 'permalin...             $16.5M
#
#                                       funding_rounds  \
# 0  [{'id': 888, 'round_code': 'a', 'source_url': ...
# 1  [{'id': 9, 'round_code': 'a', 'source_url': 'h...
# 2  [{'id': 6, 'round_code': 'a', 'source_url': ''...
#
#                                              offices
# 0  [{'description': '', 'address1': '710 - 2nd Av...
# 1  [{'description': None, 'address1': None, 'addr...
# 2  [{'description': 'Headquarters', 'address1': '...

# %%
acquisition = acquisition.replace(np.nan, 0)

# %%
acquisition.isnull().sum()
# Out:
# name                   0
# category_code          0
# number_of_employees    0
# founded_year           0
# founded_month          0
# founded_day            0
# alias_list             0
# phone_number           0
# description            0
# created_at             0
# overview               0
# relationships          0
# competitions           0
# total_money_raised     0
# funding_rounds         0
# offices                0
# dtype: int64

# %%
latitude = db.companies.find({"offices.latitude":1})
longitude = db.companies.find({"offices.longitude":1})

# %%
def geopoint(x):
    for ele in x:
        longitude = ele["longitude"]
        latitude = ele["latitude"]
        
        return{"type": "Point", "coordinates": {'longitude': longitude , 'latitude': latitude}}

acquisition["geo"] = acquisition["offices"].apply(geopoint)

# %%
b=acquisition[acquisition["geo"]=={'type': 'Point', 'coordinates': {'longitude': None, 'latitude': None}}].index
acquisition.drop(b,axis=0,inplace=True)

# %%
acquisition.dropna(subset=['geo'], inplace=True)

# %%
acquisition.geo.isnull().sum()
# Out:
# 0

# %%
#acquisition.to_json ('/home/alvaro/repositorios/office_new.json')

# %%
acquisition.to_json("office.json",orient="records", lines=True)

# %%
acquisition['geo'].value_counts()
# Out:
# {'type': 'Point', 'coordinates': {'longitude': -122.419204, 'latitude': 37.775196}}      12
# {'type': 'Point', 'coordinates': {'longitude': -95.712891, 'latitude': 37.09024}}         8
# {'type': 'Point', 'coordinates': {'longitude': 34.7595, 'latitude': 32.0554}}             4
# {'type': 'Point', 'coordinates': {'longitude': -122.159928, 'latitude': 37.437328}}       3
# {'type': 'Point', 'coordinates': {'longitude': -73.986951, 'latitude': 40.756054}}        3
#                                                                                          ..
# {'type': 'Point', 'coordinates': {'longitude': -105.228284, 'latitude': 40.026422}}       1
# {'type': 'Point', 'coordinates': {'longitude': 6.921546, 'latitude': 50.945289}}          1
# {'type': 'Point', 'coordinates': {'longitude': -118.462876, 'latitude': 34.054318}}       1
# {'type': 'Point', 'coordinates': {'longitude': -122.1797053, 'latitude': 37.4520239}}     1
# {'type': 'Point', 'coordinates': {'longitude': -122.2103414, 'latitude': 37.420728}}      1
# Name: geo, Length: 700, dtype: int64

# %%
db = client.office

# %%
near = db.office.find()
df = pd.DataFrame(near)

# %%
def geonear(geopoint, maxdistance=1000):
    return db.office.find({
        "geo":{
            "$near":{
                "$geometry":geopoint,
                "$maxDistance":maxdistance
            }}})

San_Francisco = {'type': 'Point', 'coordinates': [-122.393229, 37.781265]}

# %%
empresas = pd.DataFrame(geonear(San_Francisco,1000))

def empresas_cercanas(local):
    names = []
    lats =[]
    long=[]
    for i in empresas['geo']:
        long.append(i['coordinates']['longitude'])
        lats.append(i['coordinates']['latitude'])
    for el in empresas['category_code']:
        names.append(el)
    local = {"name":names, "latitude":lats, "longitude":long}
    return pd.DataFrame(local)
empresas_cercanas = empresas_cercanas(empresas)
empresas_cercanas.head(2)
# Out:
#           name   latitude   longitude
# 0  games_video  37.781265 -122.393229
# 1  games_video  37.780716 -122.393913

# %%
import requests
import json

url = 'https://api.foursquare.com/v2/venues/explore'

params = dict(
 client_id='HIX31VQGRL1GODLF1XYQO5ERLH1WBFWLLCAPWYHLNATD55JC',
 client_secret='3CVWFRJLEFHRKVT3HCMGEAK1ZOW1NZU3OAUOSRP2AGOTLIC2',
 v='20180323',
 ll='37.781265, -122.393229',
 query='starbucks',
 radius="1000"
 #limit=5
)

resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
import folium
from folium.plugins import HeatMap
from folium.plugins import MeasureControl

# %%
def starbucks(lugar):
   names=[]
   lats=[]
   long=[]
   for e in data['response']['groups'][0]['items']:
       names.append(e['venue']['name'])
       lats.append(e['venue']['location']['lat'])
       long.append(e['venue']['location']['lng'])
   lugar = {"name":names, "latitude":lats, "longitude":long}
   return pd.DataFrame(lugar)
starbucks = starbucks(data)
starbucks.head(2)
# Out:
#         name   latitude   longitude
# 0  Starbucks  37.778704 -122.396727
# 1  Starbucks  37.789651 -122.396622

# %%
url = 'https://api.foursquare.com/v2/venues/explore'

params_1 = dict(
  client_id='HIX31VQGRL1GODLF1XYQO5ERLH1WBFWLLCAPWYHLNATD55JC',
  client_secret='3CVWFRJLEFHRKVT3HCMGEAK1ZOW1NZU3OAUOSRP2AGOTLIC2',
  v='20180323',
  ll='37.781265, -122.393229',
  query='4bf58dd8d48988d11f941735',
)
resp = requests.get(url=url, params=params_1)
data = json.loads(resp.text)
display(data)
# Out:
# {'meta': {'code': 200, 'requestId': '5d87e8dacad1b60039575e65'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 1800,
#   'headerLocation': 'South Park',
#   'headerFullLocation': 'South Park, San Francisco',
#   'headerLocationGranularity': 'neighborhood',
#   'query': '4bf58dd8d48988d11f941735',
#   'totalResults': 15,
#   'suggestedBounds': {'ne': {'lat': 37.80628729426444,
#     'lng': -122.39330275094053},
#    'sw': {'lat': 37.763919176463595, 'lng': -122.42143572029485}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce067243644a09304c0579f',
#        'name': 'H.D. Buttercup',
#        'contact': {},
#        'location': {'address': '290 Townsend St',
#         'crossStreet': 'at 4th St.',
#         'lat': 37.77748965637303,
#         'lng': -122.39458152227482,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.77748965637303,
#           'lng': -122.39458152227482}],
#         'distance': 436,
#         'postalCode': '94107',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['290 Townsend St (at 4th St.)',
#          'San Francisco, CA 94107',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4ce067243644a09304c0579f-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ab389a1f964a520bc6d20e3',
#        'name': "Tazza D'Amore",
#        'contact': {},
#        'location': {'address': '700 4th St',
#         'crossStreet': 'at Townsend St',
#         'lat': 37.77663641001784,
#         'lng': -122.39489671292284,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.77663641001784,
#           'lng': -122.39489671292284}],
#         'distance': 535,
#         'postalCode': '94107',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['700 4th St (at Townsend St)',
#          'San Francisco, CA 94107',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '73114022'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4ab389a1f964a520bc6d20e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a5824e5f964a5206db71fe3',
#        'name': 'AMC Metreon 16',
#        'contact': {},
#        'location': {'address': '135 4th St Ste 3000',
#         'crossStreet': 'at Mission St',
#         'lat': 37.784654053391435,
#         'lng': -122.40318899435513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.784654053391435,
#           'lng': -122.40318899435513}],
#         'distance': 954,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['135 4th St Ste 3000 (at Mission St)',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'events': {'count': 16, 'summary': '16 movies'},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 5,
#         'summary': '5 people are here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 5,
#           'items': []}]}},
#       'referralId': 'e-0-4a5824e5f964a5206db71fe3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '540bd75c498ec61f46d1974d',
#        'name': "Bowl'd Acai",
#        'contact': {},
#        'location': {'address': '14 Mint Plz',
#         'crossStreet': 'at Jessie St',
#         'lat': 37.784208102657615,
#         'lng': -122.4084689655527,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.784208102657615,
#           'lng': -122.4084689655527}],
#         'distance': 1380,
#         'postalCode': '94103',
#         'cc': 'US',
#         'neighborhood': 'SoMa',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['14 Mint Plz (at Jessie St)',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-540bd75c498ec61f46d1974d-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1c59a2f964a5206b0624e3',
#        'name': 'Nordstrom',
#        'contact': {},
#        'location': {'address': '865 Market St',
#         'lat': 37.7839772,
#         'lng': -122.4071498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.7839772,
#           'lng': -122.4071498}],
#         'distance': 1261,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['865 Market St',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'referralId': 'e-0-4b1c59a2f964a5206b0624e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1ee998f964a5207b2124e3',
#        'name': 'F8 | 1192 Folsom',
#        'contact': {},
#        'location': {'address': '1192 Folsom St',
#         'crossStreet': '8th',
#         'lat': 37.77525997104541,
#         'lng': -122.40997307707066,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.77525997104541,
#           'lng': -122.40997307707066}],
#         'distance': 1617,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1192 Folsom St (8th)',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '34244067'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b1ee998f964a5207b2124e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa48566f964a520024720e3',
#        'name': 'Louise M. Davies Symphony Hall',
#        'contact': {},
#        'location': {'address': '201 Van Ness Ave',
#         'crossStreet': 'btwn Grove & Hayes St',
#         'lat': 37.7779761642689,
#         'lng': -122.42015694896058,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.7779761642689,
#           'lng': -122.42015694896058}],
#         'distance': 2397,
#         'postalCode': '94102',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['201 Van Ness Ave (btwn Grove & Hayes St)',
#          'San Francisco, CA 94102',
#          'United States']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 5,
#         'summary': '5 people are here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 5,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4aa48566f964a520024720e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57926e9b498e97a221b49a38',
#        'name': 'Laura B. Kasper, Ph.D., Psychologist',
#        'contact': {},
#        'location': {'address': '582 Market St',
#         'lat': 37.7894412,
#         'lng': -122.4016537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.7894412,
#           'lng': -122.4016537}],
#         'distance': 1173,
#         'postalCode': '94104',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['582 Market St',
#          'San Francisco, CA 94104',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d104941735',
#          'name': 'Medical Center',
#          'pluralName': 'Medical Centers',
#          'shortName': 'Medical',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '220088823'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-57926e9b498e97a221b49a38-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c58af1f6407d13a3c7db028',
#        'name': 'MUNI Bus Stop - 4th & Market',
#        'contact': {},
#        'location': {'address': '4th St',
#         'crossStreet': 'at Market',
#         'lat': 37.78566207914097,
#         'lng': -122.40622328925453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.78566207914097,
#           'lng': -122.40622328925453}],
#         'distance': 1243,
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['4th St (at Market)',
#          'San Francisco, CA',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4c58af1f6407d13a3c7db028-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '584373f6de0cbc1db77ed1b5',
#        'name': 'H.D. Buttercup',
#        'contact': {},
#        'location': {'address': '1301 16th St',
#         'lat': 37.765845,
#         'lng': -122.400239,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.765845,
#           'lng': -122.400239}],
#         'distance': 1823,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1301 16th St',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-584373f6de0cbc1db77ed1b5-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05bb09f964a520d8e122e3',
#        'name': 'Dr. Timothy Tandrow',
#        'contact': {},
#        'location': {'address': '231 Montgomery St',
#         'crossStreet': 'btwn Pine & Bush',
#         'lat': 37.791383102293786,
#         'lng': -122.4025851299943,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.791383102293786,
#           'lng': -122.4025851299943}],
#         'distance': 1395,
#         'postalCode': '94104',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['231 Montgomery St (btwn Pine & Bush)',
#          'San Francisco, CA 94104',
#          'United States']},
#        'categories': [{'id': '4d954afda243a5684865b473',
#          'name': 'Optical Shop',
#          'pluralName': 'Optical Shops',
#          'shortName': 'Optical',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b05bb09f964a520d8e122e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51e0406f498e78c0ea1bfc9b',
#        'name': 'Law Office of Amie D. Miller San Francisco Immigration Lawyer',
#        'contact': {},
#        'location': {'address': '369 Pine St Ste 725',
#         'crossStreet': '(between Montgomery & Sansome)',
#         'lat': 37.792836260144846,
#         'lng': -122.40109013474759,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.792836260144846,
#           'lng': -122.40109013474759}],
#         'distance': 1462,
#         'postalCode': '94104',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['369 Pine St Ste 725 ((between Montgomery & Sansome))',
#          'San Francisco, CA 94104',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#          'name': 'Lawyer',
#          'pluralName': 'Lawyers',
#          'shortName': 'Lawyer',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '76355448'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-51e0406f498e78c0ea1bfc9b-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54496640498e4e6cc6128617',
#        'name': 'Michael D. Ross, Attorney at Law',
#        'contact': {},
#        'location': {'address': '505 Montgomery St',
#         'crossStreet': 'Sacramento Street',
#         'lat': 37.79406424,
#         'lng': -122.4034514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.79406424,
#           'lng': -122.4034514}],
#         'distance': 1684,
#         'postalCode': '94111',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['505 Montgomery St (Sacramento Street)',
#          'San Francisco, CA 94111',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#          'name': 'Lawyer',
#          'pluralName': 'Lawyers',
#          'shortName': 'Lawyer',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '97676841'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-54496640498e4e6cc6128617-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c54c45630f92d7fe44cfaba',
#        'name': "Fior D'Italia",
#        'contact': {},
#        'location': {'address': '2237 Mason St',
#         'crossStreet': 'at Francisco',
#         'lat': 37.80436147072804,
#         'lng': -122.41344307205846,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.80436147072804,
#           'lng': -122.41344307205846}],
#         'distance': 3126,
#         'postalCode': '94133',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2237 Mason St (at Francisco)',
#          'San Francisco, CA 94133',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '91115131'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4c54c45630f92d7fe44cfaba-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5021a54be4b013b03e46d1fb',
#        'name': 'MUNI Bus Stop - Market & 8th',
#        'contact': {},
#        'location': {'address': 'Market St.',
#         'crossStreet': 'at 8th St',
#         'lat': 37.77890911560422,
#         'lng': -122.41460603674118,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.77890911560422,
#           'lng': -122.41460603674118}],
#         'distance': 1899,
#         'postalCode': '94102',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Market St. (at 8th St)',
#          'San Francisco, CA 94102',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d12b951735',
#          'name': 'Bus Line',
#          'pluralName': 'Bus Lines',
#          'shortName': 'Bus',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5021a54be4b013b03e46d1fb-14'}]}]}}

# %%
def club(lugar):
   names=[]
   lats=[]
   long=[]
   for e in data['response']['groups'][0]['items']:
       names.append(e['venue']['name'])
       lats.append(e['venue']['location']['lat'])
       long.append(e['venue']['location']['lng'])
   lugar = {"name":names, "latitude":lats, "longitude":long}
   return pd.DataFrame(lugar)
club = club(data)
club.head()
# Out:
#                                    name   latitude   longitude
# 0                        H.D. Buttercup  37.777490 -122.394582
# 1                         Tazza D'Amore  37.776636 -122.394897
# 2                        AMC Metreon 16  37.784654 -122.403189
# 3                           Bowl'd Acai  37.784208 -122.408469
# 4                             Nordstrom  37.783977 -122.407150
# 5                      F8 | 1192 Folsom  37.775260 -122.409973
# 6        Louise M. Davies Symphony Hall  37.777976 -122.420157
# 7  Laura B. Kasper, Ph.D., Psychologist  37.789441 -122.401654
# 8          MUNI Bus Stop - 4th & Market  37.785662 -122.406223
# 9                        H.D. Buttercup  37.765845 -122.400239

# %%
map_starbucks = folium.Map(location=[37.781265, -122.393229], width=750, height=500, zoom_start=15)

for index, row in starbucks.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                        radius=2,
                        icon=folium.Icon(color='red', icon='cloud'), # Icono nube, hay más en la documentación
                        
                       ).add_to(map_starbucks)
   

    folium.Circle(location=[37.781265, -122.393229],
                    radius=100
                   ).add_to(map_starbucks)

for index, row in club.iterrows(): 
    folium.Marker([row['latitude'], row['longitude']],
                        radius=2,
                        icon=folium.Icon(icon='glass'), # Icono nube, hay más en la documentación
                        fill_color="#F35C50",
                       ).add_to(map_starbucks)
    
for index, row in empresas_cercanas.iterrows(): 
    folium.Marker([row['latitude'], row['longitude']],
                        radius=2,
                        icon=folium.Icon(icon='cloud'), # Icono nube, hay más en la documentación
                        fill_color="#F35C50",
                       ).add_to(map_starbucks)

map_starbucks.add_child(MeasureControl())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
url = 'https://api.foursquare.com/v2/venues/explore'

params_2 = dict(
  client_id='HIX31VQGRL1GODLF1XYQO5ERLH1WBFWLLCAPWYHLNATD55JC',
  client_secret='3CVWFRJLEFHRKVT3HCMGEAK1ZOW1NZU3OAUOSRP2AGOTLIC2',
  v='20180323',
  ll='37.781265, -122.393229',
  query='4bf58dd8d48988d1ec931735',
)
resp_2 = requests.get(url=url, params=params_2)
data_2 = json.loads(resp_2.text)
display(data_2)
# Out:
# {'meta': {'code': 200, 'requestId': '5d87f437d69ed0002c0dbefa'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 1800,
#   'headerLocation': 'South Park',
#   'headerFullLocation': 'South Park, San Francisco',
#   'headerLocationGranularity': 'neighborhood',
#   'query': '4bf58dd8d48988d1ec931735',
#   'totalResults': 15,
#   'suggestedBounds': {'ne': {'lat': 37.80628729426444,
#     'lng': -122.3926122126231},
#    'sw': {'lat': 37.763919176463595, 'lng': -122.43593702496119}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce067243644a09304c0579f',
#        'name': 'H.D. Buttercup',
#        'contact': {},
#        'location': {'address': '290 Townsend St',
#         'crossStreet': 'at 4th St.',
#         'lat': 37.77748965637303,
#         'lng': -122.39458152227482,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.77748965637303,
#           'lng': -122.39458152227482}],
#         'distance': 436,
#         'postalCode': '94107',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['290 Townsend St (at 4th St.)',
#          'San Francisco, CA 94107',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4ce067243644a09304c0579f-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ab389a1f964a520bc6d20e3',
#        'name': "Tazza D'Amore",
#        'contact': {},
#        'location': {'address': '700 4th St',
#         'crossStreet': 'at Townsend St',
#         'lat': 37.77663641001784,
#         'lng': -122.39489671292284,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.77663641001784,
#           'lng': -122.39489671292284}],
#         'distance': 535,
#         'postalCode': '94107',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['700 4th St (at Townsend St)',
#          'San Francisco, CA 94107',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '73114022'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4ab389a1f964a520bc6d20e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a5824e5f964a5206db71fe3',
#        'name': 'AMC Metreon 16',
#        'contact': {},
#        'location': {'address': '135 4th St Ste 3000',
#         'crossStreet': 'at Mission St',
#         'lat': 37.784654053391435,
#         'lng': -122.40318899435513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.784654053391435,
#           'lng': -122.40318899435513}],
#         'distance': 954,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['135 4th St Ste 3000 (at Mission St)',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'events': {'count': 16, 'summary': '16 movies'},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 6,
#         'summary': '6 people are here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 6,
#           'items': []}]}},
#       'referralId': 'e-0-4a5824e5f964a5206db71fe3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '540bd75c498ec61f46d1974d',
#        'name': "Bowl'd Acai",
#        'contact': {},
#        'location': {'address': '14 Mint Plz',
#         'crossStreet': 'at Jessie St',
#         'lat': 37.784208102657615,
#         'lng': -122.4084689655527,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.784208102657615,
#           'lng': -122.4084689655527}],
#         'distance': 1380,
#         'postalCode': '94103',
#         'cc': 'US',
#         'neighborhood': 'SoMa',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['14 Mint Plz (at Jessie St)',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-540bd75c498ec61f46d1974d-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1c59a2f964a5206b0624e3',
#        'name': 'Nordstrom',
#        'contact': {},
#        'location': {'address': '865 Market St',
#         'lat': 37.7839772,
#         'lng': -122.4071498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.7839772,
#           'lng': -122.4071498}],
#         'distance': 1261,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['865 Market St',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b1c59a2f964a5206b0624e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1ee998f964a5207b2124e3',
#        'name': 'F8 | 1192 Folsom',
#        'contact': {},
#        'location': {'address': '1192 Folsom St',
#         'crossStreet': '8th',
#         'lat': 37.77525997104541,
#         'lng': -122.40997307707066,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.77525997104541,
#           'lng': -122.40997307707066}],
#         'distance': 1617,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1192 Folsom St (8th)',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '34244067'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b1ee998f964a5207b2124e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa48566f964a520024720e3',
#        'name': 'Louise M. Davies Symphony Hall',
#        'contact': {},
#        'location': {'address': '201 Van Ness Ave',
#         'crossStreet': 'btwn Grove & Hayes St',
#         'lat': 37.7779761642689,
#         'lng': -122.42015694896058,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.7779761642689,
#           'lng': -122.42015694896058}],
#         'distance': 2397,
#         'postalCode': '94102',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['201 Van Ness Ave (btwn Grove & Hayes St)',
#          'San Francisco, CA 94102',
#          'United States']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 6,
#         'summary': '6 people are here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 6,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4aa48566f964a520024720e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57926e9b498e97a221b49a38',
#        'name': 'Laura B. Kasper, Ph.D., Psychologist',
#        'contact': {},
#        'location': {'address': '582 Market St',
#         'lat': 37.7894412,
#         'lng': -122.4016537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.7894412,
#           'lng': -122.4016537}],
#         'distance': 1173,
#         'postalCode': '94104',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['582 Market St',
#          'San Francisco, CA 94104',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d104941735',
#          'name': 'Medical Center',
#          'pluralName': 'Medical Centers',
#          'shortName': 'Medical',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '220088823'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-57926e9b498e97a221b49a38-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c58af1f6407d13a3c7db028',
#        'name': 'MUNI Bus Stop - 4th & Market',
#        'contact': {},
#        'location': {'address': '4th St',
#         'crossStreet': 'at Market',
#         'lat': 37.78566207914097,
#         'lng': -122.40622328925453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.78566207914097,
#           'lng': -122.40622328925453}],
#         'distance': 1243,
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['4th St (at Market)',
#          'San Francisco, CA',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4c58af1f6407d13a3c7db028-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '584373f6de0cbc1db77ed1b5',
#        'name': 'H.D. Buttercup',
#        'contact': {},
#        'location': {'address': '1301 16th St',
#         'lat': 37.765845,
#         'lng': -122.400239,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.765845,
#           'lng': -122.400239}],
#         'distance': 1823,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1301 16th St',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-584373f6de0cbc1db77ed1b5-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05bb09f964a520d8e122e3',
#        'name': 'Dr. Timothy Tandrow',
#        'contact': {},
#        'location': {'address': '231 Montgomery St',
#         'crossStreet': 'btwn Pine & Bush',
#         'lat': 37.791383102293786,
#         'lng': -122.4025851299943,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.791383102293786,
#           'lng': -122.4025851299943}],
#         'distance': 1395,
#         'postalCode': '94104',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['231 Montgomery St (btwn Pine & Bush)',
#          'San Francisco, CA 94104',
#          'United States']},
#        'categories': [{'id': '4d954afda243a5684865b473',
#          'name': 'Optical Shop',
#          'pluralName': 'Optical Shops',
#          'shortName': 'Optical',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b05bb09f964a520d8e122e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51e0406f498e78c0ea1bfc9b',
#        'name': 'Law Office of Amie D. Miller San Francisco Immigration Lawyer',
#        'contact': {},
#        'location': {'address': '369 Pine St Ste 725',
#         'crossStreet': '(between Montgomery & Sansome)',
#         'lat': 37.792836260144846,
#         'lng': -122.40109013474759,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.792836260144846,
#           'lng': -122.40109013474759}],
#         'distance': 1462,
#         'postalCode': '94104',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['369 Pine St Ste 725 ((between Montgomery & Sansome))',
#          'San Francisco, CA 94104',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#          'name': 'Lawyer',
#          'pluralName': 'Lawyers',
#          'shortName': 'Lawyer',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '76355448'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-51e0406f498e78c0ea1bfc9b-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54496640498e4e6cc6128617',
#        'name': 'Michael D. Ross, Attorney at Law',
#        'contact': {},
#        'location': {'address': '505 Montgomery St',
#         'crossStreet': 'Sacramento Street',
#         'lat': 37.79406424,
#         'lng': -122.4034514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.79406424,
#           'lng': -122.4034514}],
#         'distance': 1684,
#         'postalCode': '94111',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['505 Montgomery St (Sacramento Street)',
#          'San Francisco, CA 94111',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#          'name': 'Lawyer',
#          'pluralName': 'Lawyers',
#          'shortName': 'Lawyer',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '97676841'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-54496640498e4e6cc6128617-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c54c45630f92d7fe44cfaba',
#        'name': "Fior D'Italia",
#        'contact': {},
#        'location': {'address': '2237 Mason St',
#         'crossStreet': 'at Francisco',
#         'lat': 37.80436147072804,
#         'lng': -122.41344307205846,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.80436147072804,
#           'lng': -122.41344307205846}],
#         'distance': 3126,
#         'postalCode': '94133',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2237 Mason St (at Francisco)',
#          'San Francisco, CA 94133',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '91115131'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4c54c45630f92d7fe44cfaba-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3952aaf964a520975a25e3',
#        'name': 'D&M Wines and Liquors',
#        'contact': {},
#        'location': {'address': '2200 Fillmore St',
#         'crossStreet': 'Sacramento',
#         'lat': 37.7898801380004,
#         'lng': -122.43396771530944,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.7898801380004,
#           'lng': -122.43396771530944}],
#         'distance': 3710,
#         'postalCode': '94115',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2200 Fillmore St (Sacramento)',
#          'San Francisco, CA 94115',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'shortName': 'Liquor Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b3952aaf964a520975a25e3-14'}]}]}}
