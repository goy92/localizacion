# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient("mongodb://localhost:27017/")
db = client.companies

# %%
companies = db.companies.find()

# %%
data_companies = pd.DataFrame(companies)

# %%
data_companies.head(3)
# Out:
#                         _id       name  permalink  \
# 0  52cdef7c4bab8bd675297d8b  AdventNet       abc3
# 1  52cdef7c4bab8bd675297d92    Flektor    flektor
# 2  52cdef7c4bab8bd675297d8f  Omnidrive  omnidrive
#
#                                 crunchbase_url              homepage_url  \
# 0  http://www.crunchbase.com/company/adventnet      http://adventnet.com
# 1    http://www.crunchbase.com/company/flektor    http://www.flektor.com
# 2  http://www.crunchbase.com/company/omnidrive  http://www.omnidrive.com
#
#                         blog_url  \
# 0
# 1    http://www.flektor-blog.com
# 2  http://www.omnidrive.com/blog
#
#                                        blog_feed_url twitter_username  \
# 0                                                        manageengine
# 1  http://www.flektor-blog.com/video_editing_soft...             None
# 2              http://feeds.feedburner.com/omnidrive         Nomadesk
#
#      category_code  number_of_employees  ...  video_embeds  \
# ...

# %%
data_companies.shape
# Out:
# (18801, 42)

# %%
data_companies[['total_money_raised']]
# Out:
#       total_money_raised
# 0                     $0
# 1                     $0
# 2                  $800k
# 3                     $0
# 4                 $39.8M
# ...                  ...
# 18796                 $0
# 18797                 $0
# 18798                 $0
# 18799                 $0
# 18800                 $0
#
# [18801 rows x 1 columns]

# %%
acquisition = db.companies.find({"total_money_raised":{"$regex":'M'}})

# %%
acquisition = pd.DataFrame(acquisition)

# %%
{"$and":[{"category_code":{"$eq":"design"}},

# %%
acquisition.head()
# Out:
#                         _id      name permalink  \
# 0  52cdef7c4bab8bd675297d8a  Wetpaint      abc2
# 1  52cdef7c4bab8bd675297d91      Geni      geni
# 2  52cdef7c4bab8bd675297d96    Gizmoz    gizmoz
# 3  52cdef7c4bab8bd675297d8d      Digg      digg
# 4  52cdef7c4bab8bd675297d99      Lala      lala
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 1      http://www.crunchbase.com/company/geni      http://www.geni.com
# 2    http://www.crunchbase.com/company/gizmoz        http://gizmoz.com
# 3      http://www.crunchbase.com/company/digg      http://www.digg.com
# 4      http://www.crunchbase.com/company/lala      http://www.lala.com
#
#                       blog_url                     blog_feed_url  \
# 0  http://digitalquarters.net/  http://digitalquarters.net/feed/
# 1         http://blog.geni.com    http://blog.geni.com/index.rdf
# 2
# ...
